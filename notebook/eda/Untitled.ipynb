# %%
from src.processing.coh_metrix_indices.descriptive_indices import *
import time

# %%
texto = open('/home/hansm/Documentos/Tesis_Chatbot/data/raw/txt/3/CTA/biodiversidad_docente.txt', 'r')
contenido = texto.read()
texto.close()
contenido
# Out:
# 'Presidente de la NaciŠn\nDr. N”stor Kirchner\nMinistro de EducaciŠn, Ciencia y Tecnolog™a\nLic. Daniel FilmusSecretario de EducaciŠn\nLic. Juan Carlos Tedesco\nSubsecretaria de Equidad y Calidad Educativa\nLic. Alejandra BirginDirectora Nacionalde GestiŠn Curricular y FormaciŠn Docente\nLic. Laura PitmanMinisterio de EducaciŠn, Ciencia y Tecnolog™a de la NaciŠn\nLa biodiversidad en los ecosistemas. Docentes. Cuadernos para el aula- \n1a ed. - Buenos Aires. Ministerio de EducaciŠn, Ciencia y Tecnolog™a de la NaciŠn, 2007.\n\n48 p.: il.; 17 x 24 cm. \nISBN 978-950-00-0674-3          \n\n1. FormaciŠn Docente . 2. Medio Ambiente. I. T™tulo\nCDD 371.1\nColofŠnXXXXXXX01_bio_7.qxd  12/20/07  1:31 PM  Page 201_bio_7.qxd  12/20/07  1:31 PM  Page 1Subsecretar™a de Equidad y Calidad Educativa\nçrea de producciŠn pedagŠgica \nCuadernos para el aulaCoordinaciŠn general \nAdela CoriaEquipo pedagŠgicoRosa RottembergAnal™a SegalEquipo de elaboraciŠn de contenidos\nAutor™aSilvina Chauvinçrea de prod
# ...

# %%
start = time.time()
resp = get_paragraph_count_from_text(contenido)
end = time.time()
print(end - start)
# Out:
# 0.001386404037475586

# %%
start = time.time()
resp = get_sentence_count_from_text(contenido)
end = time.time()
print(end - start)
# Out:
# 0.3510751724243164

# %%
start = time.time()
resp = get_word_count_from_text(contenido)
end = time.time()
print(end - start)
# Out:
# 0.5951390266418457

# %%
start = time.time()
resp = get_mean_of_length_of_paragraphs(contenido)
end = time.time()
print(end - start)
# Out:
# 1.0631966590881348

# %%
start = time.time()
resp = get_std_of_length_of_paragraphs(contenido)
end = time.time()
print(end - start)
# Out:
# 1.1598429679870605

# %%
start = time.time()
resp = get_mean_of_length_of_sentences(contenido)
end = time.time()
print(end - start)
# Out:
# 6.873056173324585

# %%
start = time.time()
resp = get_std_of_length_of_sentences(contenido)
end = time.time()
print(end - start)
# Out:
# 7.46308708190918

# %%
start = time.time()
resp = get_mean_of_length_of_words(contenido)
end = time.time()
print(end - start)
# Out:
# 0.6340067386627197

# %%
start = time.time()
resp = get_std_of_length_of_words(contenido, workers=-2)
end = time.time()
print(end - start)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b83a4f7374ff> in <module>
#       1 start = time.time()
# ----> 2 resp = get_std_of_length_of_words(contenido, workers=-2)
#       3 end = time.time()
#       4 print(end - start)
#
# ~/Documentos/Tesis_Chatbot/src/processing/coh_metrix_indices/descriptive_indices.py in get_std_of_length_of_words(text, language, workers)
#     286         raise ValueError(f'Language {language} is not supported yet')
#     287     elif workers == 0 or workers < -1:
# --> 288         raise ValueError('Workers must be -1 or any positive number greater than 0')
#     289     elif workers == 1:
#     290         words = split_sentence_into_words(text)
#
# ValueError: Workers must be -1 or any positive number greater than 0
